# %%
import xarray as xr
import os

# %%
path = '/gws/ssde/j25a/arctic_connect/cturrell/CMIP6/historical/AWI-ESM-1-1-LR/1850_2015/6hrPlevPt/1979_2015'
anoms = os.path.join(path, 'anoms.nc')
ds = xr.open_mfdataset(anoms)
ds
# Out:
# <xarray.Dataset> Size: 454MB
# Dimensions:           (pfull: 6, lat: 96, time: 13141)
# Coordinates:
#   * pfull             (pfull) float64 48B 925.0 850.0 700.0 600.0 500.0 250.0
#   * lat               (lat) float64 768B -88.57 -86.72 -84.86 ... 86.72 88.57
#   * time              (time) datetime64[ns] 105kB 1979-01-01 ... 2015-01-01
# Data variables:
#     ucomp_anom        (time, pfull, lat) float64 61MB dask.array<chunksize=(13141, 6, 96), meta=np.ndarray>
#     ucomp_orig        (time, pfull, lat) float32 30MB dask.array<chunksize=(13141, 6, 96), meta=np.ndarray>
#     div1_QG_anom      (time, pfull, lat) float64 61MB dask.array<chunksize=(13141, 6, 96), meta=np.ndarray>
#     div1_QG_orig      (time, pfull, lat) float64 61MB dask.array<chunksize=(13141, 6, 96), meta=np.ndarray>
#     div1_QG_123_anom  (time, pfull, lat) float64 61MB dask.array<chunksize=(13141, 6, 96), meta=np.ndarray>
# ...

# %%
ds.ucomp_anom.plot(
    x='lat',
    y='time',
    col='pfull',
    col_wrap=3  # optional: number of columns before wrapping
)
