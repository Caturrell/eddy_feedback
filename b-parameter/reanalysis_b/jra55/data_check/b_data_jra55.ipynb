# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
path = '/home/links/ct715/eddy_feedback/b-parameter/reanalysis_b/jra55/jra55_sit_plots/1979_2016/6hourly/b_dataset.nc'
ds = xr.open_dataset(path)
ds
# Out:
# <xarray.Dataset> Size: 28kB
# Dimensions:                                 (lag: 15)
# Coordinates:
#   * lag                                     (lag) int64 120B 0 1 2 ... 12 13 14
# Data variables: (12/234)
#     ucomp_va_div1_QG_va_b_n_DJF             (lag) float64 120B ...
#     ucomp_va_div1_QG_123_va_b_n_DJF         (lag) float64 120B ...
#     ucomp_va_div1_QG_gt3_va_b_n_DJF         (lag) float64 120B ...
#     ucomp_va_div1_QG_va_b_n_JFM             (lag) float64 120B ...
#     ucomp_va_div1_QG_123_va_b_n_JFM         (lag) float64 120B ...
#     ucomp_va_div1_QG_gt3_va_b_n_JFM         (lag) float64 120B ...
#     ...                                      ...
#     ucomp_500_div1_QG_500_b_s_NDJ           (lag) float64 120B ...
#     ucomp_500_div1_QG_123_500_b_s_NDJ       (lag) float64 120B ...
#     ucomp_500_div1_QG_gt3_500_b_s_NDJ       (lag) float64 120B ...
#     ucomp_500_div1_QG_500_b_s_all_time      (lag) float64 120B ...
# ...
