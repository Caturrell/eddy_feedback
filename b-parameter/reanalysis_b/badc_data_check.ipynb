# %%
import xarray as xr

# %%
path = '/badc/srip/data/zonal/original_grid'

era_i_mom = xr.open_dataset(f'{path}/era_interim/MOM_4xdaily_1979_01.nc')
era_i_mom
# Out:
# <xarray.Dataset> Size: 24MB
# Dimensions:      (time: 124, pressure: 37, latitude: 121)
# Coordinates:
#   * time         (time) datetime64[ns] 992B 1978-12-30 ... 1979-01-29T18:00:00
#   * pressure     (pressure) float32 148B 1.0 2.0 3.0 5.0 ... 950.0 975.0 1e+03
#   * latitude     (latitude) float32 484B -90.0 -88.5 -87.0 ... 87.0 88.5 90.0
# Data variables:
#     fv           (time, pressure, latitude) float32 2MB ...
#     momconv      (time, pressure, latitude) float32 2MB ...
#     uv           (time, pressure, latitude) float32 2MB ...
#     uw           (time, pressure, latitude) float32 2MB ...
#     vertflux     (time, pressure, latitude) float32 2MB ...
#     momconv_k1   (time, pressure, latitude) float32 2MB ...
#     vertflux_k1  (time, pressure, latitude) float32 2MB ...
#     momconv_k2   (time, pressure, latitude) float32 2MB ...
#     vertflux_k2  (time, pressure, latitude) float32 2MB ...
#     momconv_k3   (time, pressure, latitude) float32 2MB ...
# ...

# %%
era_i_TEM = xr.open_dataset(f'{path}/era_interim/TEM_4xdaily_1979_01.nc')
era_i_TEM
# Out:
# <xarray.Dataset> Size: 82MB
# Dimensions:         (time: 124, pressure: 37, latitude: 121)
# Coordinates:
#   * time            (time) datetime64[ns] 992B 1978-12-30 ... 1979-01-29T18:0...
#   * pressure        (pressure) float32 148B 1.0 2.0 3.0 ... 950.0 975.0 1e+03
#   * latitude        (latitude) float32 484B -90.0 -88.5 -87.0 ... 87.0 88.5 90.0
# Data variables: (12/37)
#     EPF_p_qg        (time, pressure, latitude) float32 2MB ...
#     EPF_phi_qg      (time, pressure, latitude) float32 2MB ...
#     EPFD_p_qg       (time, pressure, latitude) float32 2MB ...
#     EPFD_phi_qg     (time, pressure, latitude) float32 2MB ...
#     EPF_p_pr        (time, pressure, latitude) float32 2MB ...
#     EPF_phi_pr      (time, pressure, latitude) float32 2MB ...
#     ...              ...
#     EPFD_p_qg_k3    (time, pressure, latitude) float32 2MB ...
#     EPFD_phi_qg_k3  (time, pressure, latitude) float32 2MB ...
#     EPF_p_pr_k3     (time, pressure, latitude) float32 2MB ...
# ...

# %%
era_i_ZMD = xr.open_dataset(f'{path}/era_interim/ZMD_4xdaily_1979_01.nc')
era_i_ZMD
# Out:
# <xarray.Dataset> Size: 73MB
# Dimensions:    (time: 124, pressure: 37, latitude: 121)
# Coordinates:
#   * time       (time) datetime64[ns] 992B 1978-12-30 ... 1979-01-29T18:00:00
#   * pressure   (pressure) float32 148B 1.0 2.0 3.0 5.0 ... 950.0 975.0 1e+03
#   * latitude   (latitude) float32 484B -90.0 -88.5 -87.0 ... 87.0 88.5 90.0
# Data variables: (12/33)
#     u          (time, pressure, latitude) float32 2MB ...
#     v          (time, pressure, latitude) float32 2MB ...
#     omega      (time, pressure, latitude) float32 2MB ...
#     t          (time, pressure, latitude) float32 2MB ...
#     h          (time, pressure, latitude) float32 2MB ...
#     uu         (time, pressure, latitude) float32 2MB ...
#     ...         ...
#     vv_k3      (time, pressure, latitude) float32 2MB ...
#     tt_k3      (time, pressure, latitude) float32 2MB ...
#     uv_k3      (time, pressure, latitude) float32 2MB ...
#     uomega_k3  (time, pressure, latitude) float32 2MB ...
# ...
