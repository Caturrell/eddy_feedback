# %%
import xarray as xr
import os

# %%
path = '/gws/ssde/j25a/arctic_connect/cturrell/reanalysis_data/era5/6h_era5'

# %%
u250_path = os.path.join(path, 'u', 'u250', 'ERA5_u250_1979.nc')
u250_ds = xr.open_dataset(u250_path)
u250_ds
# Out:
# <xarray.Dataset> Size: 12GB
# Dimensions:    (time: 1460, longitude: 1440, latitude: 721)
# Coordinates:
#   * time       (time) datetime64[ns] 12kB 1979-01-01 ... 1979-12-31T18:00:00
#   * longitude  (longitude) float32 6kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#   * latitude   (latitude) float32 3kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
# Data variables:
#     u          (time, latitude, longitude) float64 12GB ...
# Attributes:
#     CDI:          Climate Data Interface version 2.0.4 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     history:      Fri May 24 11:26:54 2024: cdo selyear,1979 ERA5_u250_1979_0...
#     CDO:          Climate Data Operators version 2.0.4 (https://mpimet.mpg.de...

# %%
u500_path = os.path.join(path, 'u', 'u500', 'ERA5_u500_1979.nc')
u500_ds = xr.open_dataset(u500_path)
u500_ds
# Out:
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.10/site-packages/xarray/coding/times.py:358: CFWarning: this date/calendar/year zero convention is not supported by CF
#   cftime.num2date(num_dates, units, calendar, only_use_cftime_datetimes=True)
# /tmp/ipykernel_4056331/358801362.py:2: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates prior reform date (1582-10-15). To silence this warning specify 'use_cftime=True'.
#   u500_ds = xr.open_dataset(u500_path)
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.10/site-packages/xarray/coding/times.py:358: CFWarning: this date/calendar/year zero convention is not supported by CF
#   cftime.num2date(num_dates, units, calendar, only_use_cftime_datetimes=True)
# ...

# %%
u850_path = os.path.join(path, 'u', 'u850', 'ERA5_u850_1979.nc')
u850_ds = xr.open_dataset(u850_path)
u850_ds
# Out:
# <xarray.Dataset> Size: 515MB
# Dimensions:    (longitude: 1440, latitude: 721, time: 124)
# Coordinates:
#   * longitude  (longitude) float32 6kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#   * latitude   (latitude) float32 3kB -90.0 -89.75 -89.5 ... 89.5 89.75 90.0
#   * time       (time) datetime64[ns] 992B 1979-01-01 ... 1979-01-31T18:00:00
# Data variables:
#     u          (time, latitude, longitude) float32 515MB ...
# Attributes:
#     CDI:          Climate Data Interface version ?? (http://mpimet.mpg.de/cdi)
#     Conventions:  CF-1.6
#     history:      Fri Feb 08 11:40:52 2019: cdo invertlat /media/jc914/ERA5/u...
#     CDO:          Climate Data Operators version 1.7.0 (http://mpimet.mpg.de/...

# %%
v250_path = os.path.join(path, 'v', 'v250', 'ERA5_v250_1979.nc')
v250_ds = xr.open_dataset(v250_path)
v250_ds
# Out:
# <xarray.Dataset> Size: 12GB
# Dimensions:    (longitude: 1440, latitude: 721, time: 1460)
# Coordinates:
#   * longitude  (longitude) float32 6kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#   * latitude   (latitude) float32 3kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 12kB 1979-01-01 ... 1979-12-31T18:00:00
# Data variables:
#     v          (time, latitude, longitude) float64 12GB ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2021-01-05 21:29:09 GMT by grib_to_netcdf-2.16.0: /opt/ecmw...

# %%
v500_path = os.path.join(path, 'v', 'v500', 'ERA5_v500_1979.nc')
v500_ds = xr.open_dataset(v500_path)
v500_ds
# Out:
# <xarray.Dataset> Size: 12GB
# Dimensions:    (longitude: 1440, latitude: 721, time: 1460)
# Coordinates:
#   * longitude  (longitude) float32 6kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#   * latitude   (latitude) float32 3kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 12kB 1979-01-01 ... 1979-12-31T18:00:00
# Data variables:
#     v          (time, latitude, longitude) float64 12GB ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2021-01-05 19:00:28 GMT by grib_to_netcdf-2.16.0: /opt/ecmw...

# %%
v850_path = os.path.join(path, 'v', 'v850', 'ERA5_v850_1979.nc')
v850_ds = xr.open_dataset(v850_path)
v850_ds
# Out:
# <xarray.Dataset> Size: 515MB
# Dimensions:    (longitude: 1440, latitude: 721, time: 124)
# Coordinates:
#   * longitude  (longitude) float32 6kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#   * latitude   (latitude) float32 3kB -90.0 -89.75 -89.5 ... 89.5 89.75 90.0
#   * time       (time) datetime64[ns] 992B 1979-01-01 ... 1979-01-31T18:00:00
# Data variables:
#     v          (time, latitude, longitude) float32 515MB ...
# Attributes:
#     CDI:          Climate Data Interface version ?? (http://mpimet.mpg.de/cdi)
#     Conventions:  CF-1.6
#     history:      Tue Feb 12 15:28:13 2019: cdo invertlat /media/jc914/ERA5/v...
#     CDO:          Climate Data Operators version 1.7.0 (http://mpimet.mpg.de/...
