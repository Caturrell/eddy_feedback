# %%
import pandas as pd
df = pd.read_csv('era5_L137_model_levels.csv')

# Check row count
assert len(df) == 138

# Check a and b are zero at level 137 (surface)
assert df.iloc[-1]['a [Pa]'] == 0.0
assert df.iloc[-1]['b'] == 1.0

# Check a is zero for upper levels
assert df.iloc[1]['b'] == 0.0
