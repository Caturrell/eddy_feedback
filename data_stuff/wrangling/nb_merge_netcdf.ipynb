# %%
import netCDF4
import glob
import xarray as xr
from netCDF4 import Dataset

# %%
for i in range(100):
    
    # paths for each ensemble
    path1 = f'/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/ua/pdSST-pdSIC/MIROC6/ua_Eday_MIROC6_pdSST-pdSIC_r{i+1}i1p1f1_gn_20000601-20001231.nc'
    path2 = f'/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/ua/pdSST-pdSIC/MIROC6/ua_Eday_MIROC6_pdSST-pdSIC_r{i+1}i1p1f1_gn_20010101-20010531.nc'
    
    # make new dataset and save it
    dataset = xr.open_mfdataset([path1, path2], combine='nested', concat_dim='time')
    dataset.to_netcdf(f'/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/ua/pdSST-pdSIC/MIROC6_merged/ua_Eday_MIROC6_pdSST-pdSIC_r{i+1}i1p1f1_gn_20000601-20010531.nc')

# %%
dataset
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 365, bnds: 2, plev: 19, lat: 128, lon: 256)
# Coordinates:
#   * time       (time) datetime64[ns] 2000-06-01T12:00:00 ... 2001-05-31T12:00:00
#   * plev       (plev) float64 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * lat        (lat) float64 -88.93 -87.54 -86.14 -84.74 ... 86.14 87.54 88.93
#   * lon        (lon) float64 0.0 1.406 2.812 4.219 ... 354.4 355.8 357.2 358.6
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] dask.array<chunksize=(1, 2), meta=np.ndarray>
#     lat_bnds   (time, lat, bnds) float64 dask.array<chunksize=(214, 128, 2), meta=np.ndarray>
#     lon_bnds   (time, lon, bnds) float64 dask.array<chunksize=(214, 256, 2), meta=np.ndarray>
#     ua         (time, plev, lat, lon) float32 dask.array<chunksize=(1, 19, 128, 256), meta=np.ndarray>
# Attributes: (12/44)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            PAMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  7761.0
#     creation_date:          2020-03-31T11:22:35Z
#     ...                     ...
#     title:                  MIROC6 output prepared for CMIP6
#     variable_id:            ua
#     variant_label:          r1i1p1f1
#     license:                CMIP6 model data produced by MIROC is licensed un...
#     cmor_version:           3.5.0
#     tracking_id:            hdl:21.14100/98661d0f-2b9b-4c5d-a1fd-26b44ecc379c

# %%
ds1 = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/ua/pdSST-pdSIC/MIROC6/ua_Eday_MIROC6_pdSST-pdSIC_r1i1p1f1_gn_20000601-20001231.nc')
ds1
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 214, bnds: 2, plev: 19, lat: 128, lon: 256)
# Coordinates:
#   * time       (time) datetime64[ns] 2000-06-01T12:00:00 ... 2000-12-31T12:00:00
#   * plev       (plev) float64 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * lat        (lat) float64 -88.93 -87.54 -86.14 -84.74 ... 86.14 87.54 88.93
#   * lon        (lon) float64 0.0 1.406 2.812 4.219 ... 354.4 355.8 357.2 358.6
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] dask.array<chunksize=(1, 2), meta=np.ndarray>
#     lat_bnds   (lat, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#     lon_bnds   (lon, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#     ua         (time, plev, lat, lon) float32 dask.array<chunksize=(1, 19, 128, 256), meta=np.ndarray>
# Attributes: (12/44)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            PAMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  7761.0
#     creation_date:          2020-03-31T11:22:35Z
#     ...                     ...
#     title:                  MIROC6 output prepared for CMIP6
#     variable_id:            ua
#     variant_label:          r1i1p1f1
#     license:                CMIP6 model data produced by MIROC is licensed un...
#     cmor_version:           3.5.0
#     tracking_id:            hdl:21.14100/98661d0f-2b9b-4c5d-a1fd-26b44ecc379c
