# %%
import glob 
import xarray as xr 
import matplotlib.pyplot as plt 
import numpy as np

import sys
sys.path.append('/home/users/cturrell/documents/eddy_feedback/')

# %% [markdown]
# # Original Files

# %%
ta = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/ta/pdSST-futArcSIC/IPSL-CM6A-LR/*',
                       combine='nested', concat_dim='ens_ax', parallel=True)
ta
# Out:
# <xarray.Dataset>
# Dimensions:      (lat: 143, lon: 144, plev: 19, time: 426, ens_ax: 200,
#                   axis_nbounds: 2)
# Coordinates:
#   * lat          (lat) float32 -90.0 -88.73 -87.46 -86.2 ... 87.46 88.73 90.0
#   * lon          (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * plev         (plev) float32 1e+05 9.25e+04 8.5e+04 ... 1e+03 500.0 100.0
#   * time         (time) datetime64[ns] 2000-04-01T12:00:00 ... 2001-05-31T12:...
# Dimensions without coordinates: ens_ax, axis_nbounds
# Data variables:
#     time_bounds  (ens_ax, time, axis_nbounds) datetime64[ns] dask.array<chunksize=(1, 1, 2), meta=np.ndarray>
#     ta           (ens_ax, time, plev, lat, lon) float32 dask.array<chunksize=(1, 1, 19, 143, 144), meta=np.ndarray>
# Attributes: (12/53)
#     name:                      /ccc/work/cont003/gencmip6/p86ggas/IGCM_OUT/LM...
#     Conventions:               CF-1.7 CMIP-6.2
#     creation_date:             2019-06-19T23:08:03Z
# ...

# %%
ua = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/ta/pdSST-futArcSIC/IPSL-CM6A-LR/*',
                       combine='nested', concat_dim='ens_ax', parallel=True)
ua
# Out:
# <xarray.Dataset>
# Dimensions:      (lat: 143, lon: 144, plev: 19, time: 426, ens_ax: 200,
#                   axis_nbounds: 2)
# Coordinates:
#   * lat          (lat) float32 -90.0 -88.73 -87.46 -86.2 ... 87.46 88.73 90.0
#   * lon          (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * plev         (plev) float32 1e+05 9.25e+04 8.5e+04 ... 1e+03 500.0 100.0
#   * time         (time) datetime64[ns] 2000-04-01T12:00:00 ... 2001-05-31T12:...
# Dimensions without coordinates: ens_ax, axis_nbounds
# Data variables:
#     time_bounds  (ens_ax, time, axis_nbounds) datetime64[ns] dask.array<chunksize=(1, 1, 2), meta=np.ndarray>
#     ta           (ens_ax, time, plev, lat, lon) float32 dask.array<chunksize=(1, 1, 19, 143, 144), meta=np.ndarray>
# Attributes: (12/53)
#     name:                      /ccc/work/cont003/gencmip6/p86ggas/IGCM_OUT/LM...
#     Conventions:               CF-1.7 CMIP-6.2
#     creation_date:             2019-06-19T23:08:03Z
# ...

# %%
va = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/ta/pdSST-futArcSIC/IPSL-CM6A-LR/*',
                       combine='nested', concat_dim='ens_ax', parallel=True)
va
# Out:
# <xarray.Dataset>
# Dimensions:      (lat: 143, lon: 144, plev: 19, time: 426, ens_ax: 200,
#                   axis_nbounds: 2)
# Coordinates:
#   * lat          (lat) float32 -90.0 -88.73 -87.46 -86.2 ... 87.46 88.73 90.0
#   * lon          (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * plev         (plev) float32 1e+05 9.25e+04 8.5e+04 ... 1e+03 500.0 100.0
#   * time         (time) datetime64[ns] 2000-04-01T12:00:00 ... 2001-05-31T12:...
# Dimensions without coordinates: ens_ax, axis_nbounds
# Data variables:
#     time_bounds  (ens_ax, time, axis_nbounds) datetime64[ns] dask.array<chunksize=(1, 1, 2), meta=np.ndarray>
#     ta           (ens_ax, time, plev, lat, lon) float32 dask.array<chunksize=(1, 1, 19, 143, 144), meta=np.ndarray>
# Attributes: (12/53)
#     name:                      /ccc/work/cont003/gencmip6/p86ggas/IGCM_OUT/LM...
#     Conventions:               CF-1.7 CMIP-6.2
#     creation_date:             2019-06-19T23:08:03Z
# ...

# %% [markdown]
# ## Regridded variables

# %%
ta_files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/pdSST-futArcSIC_3x3/IPSL-CM6A-LR_3x3/ta/*.nc')
ta = xr.open_mfdataset(ta_files, combine='nested', concat_dim='ens_ax', parallel=True)
ta.ta.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)

# %%
ua_files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/pdSST-futArcSIC_3x3/IPSL-CM6A-LR_3x3/ua/*.nc')
ua = xr.open_mfdataset(ua_files, combine='nested', concat_dim='ens_ax', parallel=True)
ua.ua.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)

# %%
va_files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/pdSST-futArcSIC_3x3/IPSL-CM6A-LR_3x3/va/*.nc')
va = xr.open_mfdataset(va_files, combine='nested', concat_dim='ens_ax', parallel=True)
va.va.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)

# %% [markdown]
# # Processed Files

# %%
files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/pdSST-futArcSIC_3x3/IPSL-CM6A-LR_3x3/all/*.nc')
ds = xr.open_mfdataset(files, combine='nested', concat_dim='ens_ax', parallel=True)
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (level: 19, time: 426, lat: 61, lon: 120, ens_ax: 118)
# Coordinates:
#   * level    (level) float32 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * time     (time) datetime64[ns] 2000-04-01T12:00:00 ... 2001-05-31T12:00:00
#   * lat      (lat) int64 -90 -87 -84 -81 -78 -75 -72 ... 72 75 78 81 84 87 90
#   * lon      (lon) int64 0 3 6 9 12 15 18 21 ... 336 339 342 345 348 351 354 357
# Dimensions without coordinates: ens_ax
# Data variables:
#     ta       (ens_ax, time, level, lat, lon) float32 dask.array<chunksize=(1, 426, 19, 61, 120), meta=np.ndarray>
#     ua       (ens_ax, time, level, lat, lon) float32 dask.array<chunksize=(1, 426, 19, 61, 120), meta=np.ndarray>
#     va       (ens_ax, time, level, lat, lon) float32 dask.array<chunksize=(1, 426, 19, 61, 120), meta=np.ndarray>
#     ubar     (ens_ax, time, level, lat) float32 dask.array<chunksize=(1, 426, 19, 61), meta=np.ndarray>
# ...

# %%
ds.ta.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)

# %%
ds.ua.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20, yscale='log')

# %%
ds.va.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)

# %%
ds.div1.mean(('time', 'ens_ax')).plot.contourf(yincrease=False, levels=20)
