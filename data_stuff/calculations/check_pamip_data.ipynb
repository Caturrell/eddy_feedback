# %%
import glob 
import xarray as xr 
import matplotlib.pyplot as plt 
import numpy as np

import sys
sys.path.append('/home/users/cturrell/documents/eddy_feedback/')

# %% [markdown]
# # CanESM5

# %%
files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/CanESM5_3x3/all/*.nc')
ds = xr.open_mfdataset(files, combine='nested', concat_dim='ens_ax', parallel=True)
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 426, level: 19, lat: 61, lon: 120, ens_ax: 100)
# Coordinates:
#   * time     (time) object 2000-04-01 12:00:00 ... 2001-05-31 12:00:00
#   * level    (level) float64 100.0 500.0 1e+03 2e+03 ... 8.5e+04 9.25e+04 1e+05
#   * lat      (lat) int64 -90 -87 -84 -81 -78 -75 -72 ... 72 75 78 81 84 87 90
#   * lon      (lon) int64 0 3 6 9 12 15 18 21 ... 336 339 342 345 348 351 354 357
# Dimensions without coordinates: ens_ax
# Data variables:
#     ta       (ens_ax, time, level, lat, lon) float32 dask.array<chunksize=(1, 426, 19, 61, 120), meta=np.ndarray>
#     ua       (ens_ax, time, level, lat, lon) float32 dask.array<chunksize=(1, 426, 19, 61, 120), meta=np.ndarray>
#     va       (ens_ax, time, level, lat, lon) float32 dask.array<chunksize=(1, 426, 19, 61, 120), meta=np.ndarray>
#     ubar     (ens_ax, time, level, lat) float32 dask.array<chunksize=(1, 426, 19, 61), meta=np.ndarray>
#     ep1      (ens_ax, time, level, lat) float64 dask.array<chunksize=(1, 426, 19, 61), meta=np.ndarray>
#     ep2      (ens_ax, time, level, lat) float64 dask.array<chunksize=(1, 426, 19, 61), meta=np.ndarray>
#     div1     (ens_ax, time, level, lat) float64 dask.array<chunksize=(1, 426, 19, 61), meta=np.ndarray>
#     div2     (ens_ax, time, level, lat) float64 dask.array<chunksize=(1, 426, 19, 61), meta=np.ndarray>

# %%
ds.ta.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)

# %%
ds.ua.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)

# %%
ds.va.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)

# %%
ds.div1.mean(('time', 'ens_ax')).plot.contourf(yincrease=False, levels=20)

# %% [markdown]
# ### Original Files

# %%
ta = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/ta/pdSST-pdSIC/AWI-CM-1-1-MR/*',
                       combine='nested', concat_dim='ens_ax', parallel=True)
ta
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 365, ens_ax: 100, bnds: 2, plev: 19, lat: 192, lon: 384)
# Coordinates:
#   * time       (time) datetime64[ns] 2000-06-01T12:00:00 ... 2001-05-31T12:00:00
#   * plev       (plev) float64 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * lat        (lat) float64 -89.28 -88.36 -87.42 -86.49 ... 87.42 88.36 89.28
#   * lon        (lon) float64 0.0 0.9375 1.875 2.812 ... 356.2 357.2 358.1 359.1
# Dimensions without coordinates: ens_ax, bnds
# Data variables:
#     time_bnds  (ens_ax, time, bnds) datetime64[ns] dask.array<chunksize=(1, 1, 2), meta=np.ndarray>
#     lat_bnds   (ens_ax, lat, bnds) float64 dask.array<chunksize=(1, 192, 2), meta=np.ndarray>
#     lon_bnds   (ens_ax, lon, bnds) float64 dask.array<chunksize=(1, 384, 2), meta=np.ndarray>
#     ta         (ens_ax, time, plev, lat, lon) float32 dask.array<chunksize=(1, 1, 10, 96, 192), meta=np.ndarray>
# Attributes: (12/45)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            PAMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  0.0
#     creation_date:          2020-07-31T02:51:38Z
#     ...                     ...
#     variable_id:            ta
#     variant_label:          r100i1p1f1
#     license:                CMIP6 model data produced by Alfred Wegener Insti...
#     cmor_version:           3.4.0
#     tracking_id:            hdl:21.14100/adbd5d62-7855-4218-8840-623ed1002bcb
#     variant_info:           AWI/MPI atmosphere-only PAMIP simulations are not...

# %%
ua = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/ua/pdSST-pdSIC/AWI-CM-1-1-MR/*',
                       combine='nested', concat_dim='ens_ax', parallel=True)
ua
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 365, ens_ax: 100, bnds: 2, plev: 19, lat: 192, lon: 384)
# Coordinates:
#   * time       (time) datetime64[ns] 2000-06-01T12:00:00 ... 2001-05-31T12:00:00
#   * plev       (plev) float64 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * lat        (lat) float64 -89.28 -88.36 -87.42 -86.49 ... 87.42 88.36 89.28
#   * lon        (lon) float64 0.0 0.9375 1.875 2.812 ... 356.2 357.2 358.1 359.1
# Dimensions without coordinates: ens_ax, bnds
# Data variables:
#     time_bnds  (ens_ax, time, bnds) datetime64[ns] dask.array<chunksize=(1, 1, 2), meta=np.ndarray>
#     lat_bnds   (ens_ax, lat, bnds) float64 dask.array<chunksize=(1, 192, 2), meta=np.ndarray>
#     lon_bnds   (ens_ax, lon, bnds) float64 dask.array<chunksize=(1, 384, 2), meta=np.ndarray>
#     ua         (ens_ax, time, plev, lat, lon) float32 dask.array<chunksize=(1, 1, 10, 96, 192), meta=np.ndarray>
# Attributes: (12/45)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            PAMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  0.0
#     creation_date:          2020-07-31T02:51:31Z
#     ...                     ...
#     variable_id:            ua
#     variant_label:          r100i1p1f1
#     license:                CMIP6 model data produced by Alfred Wegener Insti...
#     cmor_version:           3.4.0
#     tracking_id:            hdl:21.14100/1d35c12b-fce8-41af-9c25-388270f0ecf6
#     variant_info:           AWI/MPI atmosphere-only PAMIP simulations are not...

# %%
va = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/va/pdSST-pdSIC/AWI-CM-1-1-MR/*',
                       combine='nested', concat_dim='ens_ax', parallel=True)
va
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 365, ens_ax: 100, bnds: 2, plev: 19, lat: 192, lon: 384)
# Coordinates:
#   * time       (time) datetime64[ns] 2000-06-01T12:00:00 ... 2001-05-31T12:00:00
#   * plev       (plev) float64 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * lat        (lat) float64 -89.28 -88.36 -87.42 -86.49 ... 87.42 88.36 89.28
#   * lon        (lon) float64 0.0 0.9375 1.875 2.812 ... 356.2 357.2 358.1 359.1
# Dimensions without coordinates: ens_ax, bnds
# Data variables:
#     time_bnds  (ens_ax, time, bnds) datetime64[ns] dask.array<chunksize=(1, 1, 2), meta=np.ndarray>
#     lat_bnds   (ens_ax, lat, bnds) float64 dask.array<chunksize=(1, 192, 2), meta=np.ndarray>
#     lon_bnds   (ens_ax, lon, bnds) float64 dask.array<chunksize=(1, 384, 2), meta=np.ndarray>
#     va         (ens_ax, time, plev, lat, lon) float32 dask.array<chunksize=(1, 1, 10, 96, 192), meta=np.ndarray>
# Attributes: (12/45)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            PAMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  0.0
#     creation_date:          2020-07-31T02:51:38Z
#     ...                     ...
#     variable_id:            va
#     variant_label:          r100i1p1f1
#     license:                CMIP6 model data produced by Alfred Wegener Insti...
#     cmor_version:           3.4.0
#     tracking_id:            hdl:21.14100/2d8bb63b-0ef2-4c81-b185-77790fafd863
#     variant_info:           AWI/MPI atmosphere-only PAMIP simulations are not...

# %%
va.plev
# Out:
# <xarray.DataArray 'plev' (plev: 8)>
# array([100000.,  85000.,  70000.,  50000.,  25000.,  10000.,   5000.,   1000.])
# Coordinates:
#   * plev     (plev) float64 1e+05 8.5e+04 7e+04 5e+04 2.5e+04 1e+04 5e+03 1e+03
# Attributes:
#     units:          Pa
#     axis:           Z
#     positive:       down
#     long_name:      pressure
#     standard_name:  air_pressure

# %% [markdown]
# ## Regridded variables

# %%
break

# %% [markdown]
# ### CanESM5

# %%
ta_files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/CanESM5_3x3/ta/*.nc')
ta = xr.open_mfdataset(ta_files, combine='nested', concat_dim='ens_ax', parallel=True)
ta.ta.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)

# %%
ua_files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/CanESM5_3x3/ua/*.nc')
ua = xr.open_mfdataset(ua_files, combine='nested', concat_dim='ens_ax', parallel=True)
ua.ua.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)

# %%
va_files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/CanESM5_3x3/va/*.nc')
va = xr.open_mfdataset(va_files, combine='nested', concat_dim='ens_ax', parallel=True)
va.va.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)
