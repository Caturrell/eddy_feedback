# %%
import glob 
import xarray as xr 
import matplotlib.pyplot as plt 
import numpy as np

import sys
sys.path.append('/home/users/cturrell/documents/eddy_feedback/')

# %% [markdown]
# # Original Files

# %%
ta = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/ta/pdSST-pdSIC/MIROC6/*',
                       combine='nested', concat_dim='ens_ax', parallel=True)
ta
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 365, plev: 19, lat: 128, lon: 256, ens_ax: 200, bnds: 2)
# Coordinates:
#   * time       (time) datetime64[ns] 2000-06-01T12:00:00 ... 2001-05-31T12:00:00
#   * plev       (plev) float64 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * lat        (lat) float64 -88.93 -87.54 -86.14 -84.74 ... 86.14 87.54 88.93
#   * lon        (lon) float64 0.0 1.406 2.812 4.219 ... 354.4 355.8 357.2 358.6
# Dimensions without coordinates: ens_ax, bnds
# Data variables:
#     time_bnds  (ens_ax, time, bnds) datetime64[ns] dask.array<chunksize=(1, 1, 2), meta=np.ndarray>
#     lat_bnds   (ens_ax, lat, bnds) float64 dask.array<chunksize=(1, 128, 2), meta=np.ndarray>
#     lon_bnds   (ens_ax, lon, bnds) float64 dask.array<chunksize=(1, 256, 2), meta=np.ndarray>
#     ta         (ens_ax, time, plev, lat, lon) float32 dask.array<chunksize=(1, 1, 19, 128, 256), meta=np.ndarray>
# Attributes: (12/44)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            PAMIP
#     branch_method:          standard
#     branch_time_in_child:   -91.0
#     branch_time_in_parent:  4018.0
#     creation_date:          2020-03-31T20:02:51Z
#     ...                     ...
#     title:                  MIROC6 output prepared for CMIP6
#     variable_id:            ta
#     variant_label:          r100i1p1f1
#     license:                CMIP6 model data produced by MIROC is licensed un...
#     cmor_version:           3.5.0
#     tracking_id:            hdl:21.14100/3ca95b11-a37a-4cb7-8f37-8ee90c2f7de2

# %%
ua = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/ua/pdSST-pdSIC/MIROC6/*',
                       combine='nested', concat_dim='ens_ax', parallel=True)
ua
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 365, plev: 19, lat: 128, lon: 256, ens_ax: 200, bnds: 2)
# Coordinates:
#   * time       (time) datetime64[ns] 2000-06-01T12:00:00 ... 2001-05-31T12:00:00
#   * plev       (plev) float64 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * lat        (lat) float64 -88.93 -87.54 -86.14 -84.74 ... 86.14 87.54 88.93
#   * lon        (lon) float64 0.0 1.406 2.812 4.219 ... 354.4 355.8 357.2 358.6
# Dimensions without coordinates: ens_ax, bnds
# Data variables:
#     time_bnds  (ens_ax, time, bnds) datetime64[ns] dask.array<chunksize=(1, 1, 2), meta=np.ndarray>
#     lat_bnds   (ens_ax, lat, bnds) float64 dask.array<chunksize=(1, 128, 2), meta=np.ndarray>
#     lon_bnds   (ens_ax, lon, bnds) float64 dask.array<chunksize=(1, 256, 2), meta=np.ndarray>
#     ua         (ens_ax, time, plev, lat, lon) float32 dask.array<chunksize=(1, 1, 19, 128, 256), meta=np.ndarray>
# Attributes: (12/44)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            PAMIP
#     branch_method:          standard
#     branch_time_in_child:   -91.0
#     branch_time_in_parent:  4018.0
#     creation_date:          2020-03-31T20:03:30Z
#     ...                     ...
#     title:                  MIROC6 output prepared for CMIP6
#     variable_id:            ua
#     variant_label:          r100i1p1f1
#     license:                CMIP6 model data produced by MIROC is licensed un...
#     cmor_version:           3.5.0
#     tracking_id:            hdl:21.14100/a7d29f90-ab3b-4e2b-adba-d3811391f4ca

# %%
va = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/va/pdSST-pdSIC/MIROC6/*',
                       combine='nested', concat_dim='ens_ax', parallel=True)
va
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 365, plev: 19, lat: 128, lon: 256, ens_ax: 200, bnds: 2)
# Coordinates:
#   * time       (time) datetime64[ns] 2000-06-01T12:00:00 ... 2001-05-31T12:00:00
#   * plev       (plev) float64 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * lat        (lat) float64 -88.93 -87.54 -86.14 -84.74 ... 86.14 87.54 88.93
#   * lon        (lon) float64 0.0 1.406 2.812 4.219 ... 354.4 355.8 357.2 358.6
# Dimensions without coordinates: ens_ax, bnds
# Data variables:
#     time_bnds  (ens_ax, time, bnds) datetime64[ns] dask.array<chunksize=(1, 1, 2), meta=np.ndarray>
#     lat_bnds   (ens_ax, lat, bnds) float64 dask.array<chunksize=(1, 128, 2), meta=np.ndarray>
#     lon_bnds   (ens_ax, lon, bnds) float64 dask.array<chunksize=(1, 256, 2), meta=np.ndarray>
#     va         (ens_ax, time, plev, lat, lon) float32 dask.array<chunksize=(1, 1, 19, 128, 256), meta=np.ndarray>
# Attributes: (12/44)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            PAMIP
#     branch_method:          standard
#     branch_time_in_child:   -91.0
#     branch_time_in_parent:  4018.0
#     creation_date:          2020-03-31T20:04:12Z
#     ...                     ...
#     title:                  MIROC6 output prepared for CMIP6
#     variable_id:            va
#     variant_label:          r100i1p1f1
#     license:                CMIP6 model data produced by MIROC is licensed un...
#     cmor_version:           3.5.0
#     tracking_id:            hdl:21.14100/7121a36e-7b98-4f29-bee7-83b318753874

# %% [markdown]
# # Processed Files

# %%
files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/pdSST-futArcSIC_3x3/AWI-CM-1-1-MR_3x3/all/*.nc')
ds = xr.open_mfdataset(files, combine='nested', concat_dim='ens_ax', parallel=True)
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 365, level: 19, lat: 61, lon: 120, ens_ax: 100)
# Coordinates:
#   * time     (time) datetime64[ns] 2000-06-01T12:00:00 ... 2001-05-31T12:00:00
#   * level    (level) float64 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * lat      (lat) int64 -90 -87 -84 -81 -78 -75 -72 ... 72 75 78 81 84 87 90
#   * lon      (lon) int64 0 3 6 9 12 15 18 21 ... 336 339 342 345 348 351 354 357
# Dimensions without coordinates: ens_ax
# Data variables:
#     ta       (ens_ax, time, level, lat, lon) float32 dask.array<chunksize=(1, 365, 19, 61, 120), meta=np.ndarray>
#     ua       (ens_ax, time, level, lat, lon) float32 dask.array<chunksize=(1, 365, 19, 61, 120), meta=np.ndarray>
#     va       (ens_ax, time, level, lat, lon) float32 dask.array<chunksize=(1, 365, 19, 61, 120), meta=np.ndarray>
#     ubar     (ens_ax, time, level, lat) float32 dask.array<chunksize=(1, 365, 19, 61), meta=np.ndarray>
#     ep1      (ens_ax, time, level, lat) float64 dask.array<chunksize=(1, 365, 19, 61), meta=np.ndarray>
#     ep2      (ens_ax, time, level, lat) float64 dask.array<chunksize=(1, 365, 19, 61), meta=np.ndarray>
#     div1     (ens_ax, time, level, lat) float64 dask.array<chunksize=(1, 365, 19, 61), meta=np.ndarray>
#     div2     (ens_ax, time, level, lat) float64 dask.array<chunksize=(1, 365, 19, 61), meta=np.ndarray>

# %%
ds.ta.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)

# %%
ds.ua.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20, yscale='log')

# %%
ds.va.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)

# %%
ds.div1.mean(('time', 'ens_ax')).plot.contourf(yincrease=False, levels=20)

# %% [markdown]
# ## Regridded variables

# %%
ta_files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/pdSST-futArcSIC_3x3/AWI-CM-1-1-MR_3x3/ta/*.nc')
ta = xr.open_mfdataset(ta_files, combine='nested', concat_dim='ens_ax', parallel=True)
ta.ta.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)

# %%
ua_files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/pdSST-futArcSIC_3x3/AWI-CM-1-1-MR_3x3/ua/*.nc')
ua = xr.open_mfdataset(ua_files, combine='nested', concat_dim='ens_ax', parallel=True)
ua.ua.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)

# %%
va_files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/pdSST-futArcSIC_3x3/AWI-CM-1-1-MR_3x3/va/*.nc')
va = xr.open_mfdataset(va_files, combine='nested', concat_dim='ens_ax', parallel=True)
va.va.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)
