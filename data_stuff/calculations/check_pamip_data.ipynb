# %%
import glob 
import xarray as xr 
import matplotlib.pyplot as plt 
import numpy as np

import sys
sys.path.append('/home/users/cturrell/documents/eddy_feedback/')

# %% [markdown]
# ## Completed Models

# %%
files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/FGOALS-f3-L_3x3/all/*.nc')
ds = xr.open_mfdataset(files, combine='nested', concat_dim='ens_ax', parallel=True)
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 456, level: 8, lat: 61, lon: 120, ens_ax: 100)
# Coordinates:
#   * time     (time) object 2000-04-01 12:00:00 ... 2001-06-30 12:00:00
#   * level    (level) float64 1e+05 8.5e+04 7e+04 5e+04 2.5e+04 1e+04 5e+03 1e+03
#   * lat      (lat) int64 -90 -87 -84 -81 -78 -75 -72 ... 72 75 78 81 84 87 90
#   * lon      (lon) int64 0 3 6 9 12 15 18 21 ... 336 339 342 345 348 351 354 357
# Dimensions without coordinates: ens_ax
# Data variables:
#     ta       (ens_ax, time, level, lat, lon) float32 dask.array<chunksize=(1, 456, 8, 61, 120), meta=np.ndarray>
#     ua       (ens_ax, time, level, lat, lon) float32 dask.array<chunksize=(1, 456, 8, 61, 120), meta=np.ndarray>
#     va       (ens_ax, time, level, lat, lon) float32 dask.array<chunksize=(1, 456, 8, 61, 120), meta=np.ndarray>
#     ubar     (ens_ax, time, level, lat) float32 dask.array<chunksize=(1, 456, 8, 61), meta=np.ndarray>
#     ep1      (ens_ax, time, level, lat) float64 dask.array<chunksize=(1, 456, 8, 61), meta=np.ndarray>
#     ep2      (ens_ax, time, level, lat) float64 dask.array<chunksize=(1, 456, 8, 61), meta=np.ndarray>
#     div1     (ens_ax, time, level, lat) float64 dask.array<chunksize=(1, 456, 8, 61), meta=np.ndarray>
#     div2     (ens_ax, time, level, lat) float64 dask.array<chunksize=(1, 456, 8, 61), meta=np.ndarray>

# %%
ds.ta.mean(('time', 'ens_ax', 'lon')).plot.contourf(yincrease=False, levels=20)

# %%
ds.ua.mean(('time', 'ens_ax', 'lon')).plot.contourf(yincrease=False, levels=20)

# %%
ds.va.mean(('time', 'ens_ax', 'lon')).plot.contourf(yincrease=False, levels=20)

# %% [markdown]
# ## Regridded variables

# %%
ta_files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/CanESM5_3x3/ta/*.nc')
ta = xr.open_mfdataset(ta_files, combine='nested', concat_dim='ens_ax', parallel=True)
ta.ta.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 ta_files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/CanESM5_3x3/ta/*.nc')
#       2 ta = xr.open_mfdataset(ta_files, combine='nested', concat_dim='ens_ax', parallel=True)
# ----> 3 ta.ta.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)
#
# File ~/miniforge3/envs/eddy/lib/python3.12/site-packages/xarray/plot/accessor.py:681, in DataArrayPlotAccessor.contourf(self, *args, **kwargs)
#     679 @functools.wraps(dataarray_plot.contourf, assigned=("__doc__",))
#     680 def contourf(self, *args, **kwargs) -> QuadContourSet | FacetGrid[DataArray]:
# --> 681     return dataarray_plot.contourf(self._da, *args, **kwargs)
#
# File ~/miniforge3/envs/eddy/lib/python3.12/site-packages/xarray/plot/dataarray_plot.py:1577, in _plot2d.<locals>.newplotfunc(***failed resolving arguments***)
#    1574 yvalnp = yval.to_numpy()
#    1576 # Pass the data as a masked ndarray too
# -> 1577 zval = darray.to_masked_array(copy=False)
#    1579 # Replace pd.Intervals if contained in xval or yval.
#    1580 xplt, xlab_extra = _resolve_intervals_2dplot(xvalnp, plotfunc.__name__)
#
# File ~/miniforge3/envs/eddy/lib/python3.12/site-packages/xarray/core/dataarray.py:3892, in DataArray.to_masked_array(self, copy)
#    3878 def to_masked_array(self, copy: bool = True) -> np.ma.MaskedArray:
#    3879     """Convert this array into a numpy.ma.MaskedArray
#    3880
#    3881     Parameters
#    (...)
#    3890         Masked where invalid values (nan or inf) occur.
#    3891     """
# -> 3892     values = self.to_numpy()  # only compute lazy arrays once
#    3893     isnull = pd.isnull(values)
#    3894     return np.ma.MaskedArray(data=values, mask=isnull, copy=copy)
#
# File ~/miniforge3/envs/eddy/lib/python3.12/site-packages/xarray/core/dataarray.py:788, in DataArray.to_numpy(self)
#     777 def to_numpy(self) -> np.ndarray:
#     778     """
#     779     Coerces wrapped data to numpy and returns a numpy.ndarray.
#     780
#    (...)
#     786     DataArray.data
#     787     """
# --> 788     return self.variable.to_numpy()
#
# File ~/miniforge3/envs/eddy/lib/python3.12/site-packages/xarray/core/variable.py:1091, in Variable.to_numpy(self)
#    1089 """Coerces wrapped data to numpy and returns a numpy.ndarray"""
#    1090 # TODO an entrypoint so array libraries can choose coercion method?
# -> 1091 return to_numpy(self._data)
#
# File ~/miniforge3/envs/eddy/lib/python3.12/site-packages/xarray/core/pycompat.py:116, in to_numpy(data)
#     114 if hasattr(data, "chunks"):
#     115     chunkmanager = get_chunked_array_type(data)
# --> 116     data, *_ = chunkmanager.compute(data)
#     117 if isinstance(data, array_type("cupy")):
#     118     data = data.get()
#
# File ~/miniforge3/envs/eddy/lib/python3.12/site-packages/xarray/core/daskmanager.py:70, in DaskManager.compute(self, *data, **kwargs)
#      67 def compute(self, *data: DaskArray, **kwargs) -> tuple[np.ndarray, ...]:
#      68     from dask.array import compute
# ---> 70     return compute(*data, **kwargs)
#
# File ~/miniforge3/envs/eddy/lib/python3.12/site-packages/dask/base.py:628, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     625     postcomputes.append(x.__dask_postcompute__())
#     627 with shorten_traceback():
# --> 628     results = schedule(dsk, keys, **kwargs)
#     630 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/miniforge3/envs/eddy/lib/python3.12/queue.py:171, in Queue.get(self, block, timeout)
#     169 elif timeout is None:
#     170     while not self._qsize():
# --> 171         self.not_empty.wait()
#     172 elif timeout < 0:
#     173     raise ValueError("'timeout' must be a non-negative number")
#
# File ~/miniforge3/envs/eddy/lib/python3.12/threading.py:334, in Condition.wait(self, timeout)
#     332 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     333     if timeout is None:
# --> 334         waiter.acquire()
#     335         gotit = True
#     336     else:
#
# KeyboardInterrupt:

# %%
ua_files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/CanESM5_3x3/ua/*.nc')
ua = xr.open_mfdataset(ua_files, combine='nested', concat_dim='ens_ax', parallel=True)
ua.ua.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)

# %%
va_files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/CanESM5_3x3/va/*.nc')
va = xr.open_mfdataset(va_files, combine='nested', concat_dim='ens_ax', parallel=True)
va.va.mean(('ens_ax', 'time', 'lon')).plot.contourf(yincrease=False, levels=20)
# Out:
# <xarray.Dataset>
# Dimensions:  (ens_ax: 100, time: 426, level: 8, lat: 61, lon: 120)
# Coordinates:
#   * time     (time) object 2000-04-01 12:00:00 ... 2001-05-31 12:00:00
#   * level    (level) float64 1e+05 8.5e+04 7e+04 5e+04 2.5e+04 1e+04 5e+03 1e+03
#   * lat      (lat) int64 -90 -87 -84 -81 -78 -75 -72 ... 72 75 78 81 84 87 90
#   * lon      (lon) int64 0 3 6 9 12 15 18 21 ... 336 339 342 345 348 351 354 357
# Dimensions without coordinates: ens_ax
# Data variables:
#     va       (ens_ax, time, level, lat, lon) float32 dask.array<chunksize=(1, 426, 8, 61, 120), meta=np.ndarray>
# Attributes:
#     regrid_method:  bilinear
