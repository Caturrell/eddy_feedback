# %%
import xarray as xr 
import glob

# %%
files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/*/pdSST-pdSIC/AWI-CM-1-1-MR/*.nc')

ds = xr.open_mfdataset(files, combine='nested', concat_dim='ens_ax', parallel=True)
ds
# Out:
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/dask/array/core.py:4836: PerformanceWarning: Increasing number of chunks by factor of 100
#   result = blockwise(
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/dask/array/core.py:4836: PerformanceWarning: Increasing number of chunks by factor of 100
#   result = blockwise(
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/dask/array/core.py:4836: PerformanceWarning: Increasing number of chunks by factor of 100
#   result = blockwise(
# <xarray.Dataset>
# Dimensions:    (time: 365, ens_ax: 300, bnds: 2, plev: 19, lat: 192, lon: 384)
# Coordinates:
#   * time       (time) datetime64[ns] 2000-06-01T12:00:00 ... 2001-05-31T12:00:00
#   * plev       (plev) float64 1e+05 9.25e+04 8.5e+04 7e+04 ... 1e+03 500.0 100.0
#   * lat        (lat) float64 -89.28 -88.36 -87.42 -86.49 ... 87.42 88.36 89.28
# ...

# %%
files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/*/pdSST-pdSIC/CanESM5/*.nc')

ds = xr.open_mfdataset(files, combine='nested', concat_dim='ens_ax', parallel=True)

ds
# Out:
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/dask/array/core.py:4836: PerformanceWarning: Increasing number of chunks by factor of 100
#   result = blockwise(
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/dask/array/core.py:4836: PerformanceWarning: Increasing number of chunks by factor of 100
#   result = blockwise(
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/dask/array/core.py:4836: PerformanceWarning: Increasing number of chunks by factor of 100
#   result = blockwise(
# <xarray.Dataset>
# Dimensions:    (time: 426, plev: 19, lat: 64, lon: 128, ens_ax: 300, bnds: 2)
# Coordinates:
#   * time       (time) object 2000-04-01 12:00:00 ... 2001-05-31 12:00:00
#   * plev       (plev) float64 100.0 500.0 1e+03 2e+03 ... 8.5e+04 9.25e+04 1e+05
#   * lat        (lat) float64 -87.86 -85.1 -82.31 -79.53 ... 82.31 85.1 87.86
#   * lon        (lon) float64 0.0 2.812 5.625 8.438 ... 348.8 351.6 354.4 357.2
# ...

# %%
files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/*/pdSST-pdSIC/CNRM-CM6-1/*.nc')

ds = xr.open_mfdataset(files, combine='nested', concat_dim='ens_ax', parallel=True)

ds
# Out:
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/xarray/core/indexing.py:1446: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/dask/array/core.py:4836: PerformanceWarning: Increasing number of chunks by factor of 300
#   result = blockwise(
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/xarray/core/indexing.py:1446: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
# ...

# %%
files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/*/pdSST-pdSIC/FGOALS-f3-L/*.nc')

ds = xr.open_mfdataset(files, combine='nested', concat_dim='ens_ax', parallel=True)

ds
# Out:
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/xarray/core/indexing.py:1446: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/xarray/core/indexing.py:1446: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
# ...

# %%
files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/*/pdSST-pdSIC/HadGEM3-GC31-MM/*.nc')

ds = xr.open_mfdataset(files, combine='nested', concat_dim='ens_ax', parallel=True)

ds
# Out:
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/xarray/core/indexing.py:1452: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   value = value[(slice(None),) * axis + (subkey,)]
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/xarray/core/indexing.py:1452: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
# ...

# %%
files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/*/pdSST-pdSIC/IPSL-CM6A-LR/*.nc')

ds = xr.open_mfdataset(files, combine='nested', concat_dim='ens_ax', parallel=True)

ds
# Out:
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/dask/array/core.py:4836: PerformanceWarning: Increasing number of chunks by factor of 200
#   result = blockwise(
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/dask/array/core.py:4836: PerformanceWarning: Increasing number of chunks by factor of 200
#   result = blockwise(
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/dask/array/core.py:4836: PerformanceWarning: Increasing number of chunks by factor of 200
#   result = blockwise(
# <xarray.Dataset>
# Dimensions:      (lat: 143, lon: 144, plev: 19, time: 426, ens_ax: 600,
#                   axis_nbounds: 2)
# Coordinates:
#   * lat          (lat) float32 -90.0 -88.73 -87.46 -86.2 ... 87.46 88.73 90.0
#   * lon          (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * plev         (plev) float32 1e+05 9.25e+04 8.5e+04 ... 1e+03 500.0 100.0
# ...

# %%
files = glob.glob('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/daily/*/pdSST-pdSIC/MIROC6/*.nc')

ds = xr.open_mfdataset(files, combine='nested', concat_dim='ens_ax', parallel=True)

ds
# Out:
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/xarray/core/indexing.py:1446: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/dask/array/core.py:4836: PerformanceWarning: Increasing number of chunks by factor of 200
#   result = blockwise(
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/xarray/core/indexing.py:1446: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
# ...
