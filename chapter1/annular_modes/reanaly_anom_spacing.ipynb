# %%
import xarray as xr
import os
import numpy as np
import matplotlib.pyplot as plt
from eofs.xarray import Eof
import xcdat

import functions.data_wrangling as dw
import annular_modes as am

# %%
path = '/home/links/ct715/data_storage/reanalysis/jra55_daily'
data_file = os.path.join(path, 'jra55_uvtw.nc')
ds = xr.open_mfdataset(data_file, chunks={'time': 30})
ds = ds.bounds.add_missing_bounds(axes='T')
ds
# Out:
# <xarray.Dataset> Size: 134GB
# Dimensions:    (time: 21550, level: 37, lat: 73, lon: 144, bnds: 2)
# Coordinates:
#   * time       (time) datetime64[ns] 172kB 1958-01-01T09:00:00 ... 2016-12-31...
#   * lon        (lon) float64 1kB 0.0 2.5 5.0 7.5 ... 350.0 352.5 355.0 357.5
#   * lat        (lat) float64 584B 90.0 87.5 85.0 82.5 ... -85.0 -87.5 -90.0
#   * level      (level) float64 296B 1.0 2.0 3.0 5.0 ... 925.0 950.0 975.0 1e+03
# Dimensions without coordinates: bnds
# Data variables:
#     u          (time, level, lat, lon) float32 34GB dask.array<chunksize=(30, 37, 73, 144), meta=np.ndarray>
#     v          (time, level, lat, lon) float32 34GB dask.array<chunksize=(30, 37, 73, 144), meta=np.ndarray>
#     t          (time, level, lat, lon) float32 34GB dask.array<chunksize=(30, 37, 73, 144), meta=np.ndarray>
#     omega      (time, level, lat, lon) float32 34GB dask.array<chunksize=(30, 37, 73, 144), meta=np.ndarray>
# ...

# %% [markdown]
# # Daily anomalies (1979-2010)

# %%
am.run_eof_calculations_and_plot(ds, data_freq='day', time_frame='all-time', time_period='simpson')
# Out:
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_all-time_daily_anom_100-1000hPa.nc
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_va_all-time_daily_anom_100-1000hPa.nc

# %%
am.run_eof_calculations_and_plot(ds, data_freq='day', time_frame='all-time', time_period='simpson', calc_mon_avg=True)
# Out:
# Calculating monthly averages...
# Computing EOFs and saving to /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_all-time_daily_anom_mon-avg_100-1000hPa.nc
# Calculating monthly averages...
# Computing EOFs and saving to /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_va_all-time_daily_anom_mon-avg_100-1000hPa.nc

# %%
am.run_eof_calculations_and_plot(ds, data_freq='day', time_frame='jja', time_period='simpson')
# Out:
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_JJA_daily_anom_100-1000hPa.nc
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_va_JJA_daily_anom_100-1000hPa.nc

# %%
am.run_eof_calculations_and_plot(ds, data_freq='day', time_frame='jja', time_period='simpson', calc_mon_avg=True)
# Out:
# Calculating monthly averages...
# Computing EOFs and saving to /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_JJA_daily_anom_mon-avg_100-1000hPa.nc
# Calculating monthly averages...
# Computing EOFs and saving to /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_va_JJA_daily_anom_mon-avg_100-1000hPa.nc

# %% [markdown]
# # Spaced daily anomalies (1979-2010)
#
# Not needed anomalies have been turned into NaN rather than the whole dataset subsetted.

# %%
am.run_eof_calculations_and_plot(ds, data_freq='day', time_frame='jja', time_period='simpson', mask_non_seasonal=True)
# Out:
# Computing EOFs and saving to /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_JJA_daily_anom_masked_100-1000hPa.nc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 am.run_eof_calculations_and_plot(ds, data_freq='day', time_frame='jja', time_period='simpson', mask_non_seasonal=True)
#
# File ~/eddy_feedback/chapter1/annular_modes/annular_modes.py:194, in run_eof_calculations_and_plot(ds, data_var, data_freq, time_frame, time_period, hemisphere, calc_mon_avg, mask_non_seasonal)
#     174 """
#     175 Compute and plot both the standard and vertically weighted EOFs for a given anomaly frequency,
#     176 time frame, and time period.
#    (...)
#     191     Default is 'full'.
#     192 """
#     193 # Compute both the standard and vertically weighted EOF datasets.
# ...

# %%
am.run_eof_calculations_and_plot(ds, data_freq='day', time_frame='djf', time_period='simpson', mask_non_seasonal=True)
# Out:
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_DJF_szn_anom_100-1000hPa.nc
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_va_DJF_szn_anom_100-1000hPa.nc
