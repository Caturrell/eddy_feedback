# %%
import xarray as xr
import os
import numpy as np
import matplotlib.pyplot as plt
from eofs.xarray import Eof
import xcdat

import functions.data_wrangling as dw
import annular_modes as am

# %%
path = '/home/links/ct715/data_storage/reanalysis/jra55_daily'
data_file = os.path.join(path, 'jra55_uvtw.nc')
ds = xr.open_mfdataset(data_file, chunks={'time': 30})
ds = ds.bounds.add_missing_bounds(axes='T')
ds
# Out:
# <xarray.Dataset> Size: 134GB
# Dimensions:    (time: 21550, level: 37, lat: 73, lon: 144, bnds: 2)
# Coordinates:
#   * time       (time) datetime64[ns] 172kB 1958-01-01T09:00:00 ... 2016-12-31...
#   * lon        (lon) float64 1kB 0.0 2.5 5.0 7.5 ... 350.0 352.5 355.0 357.5
#   * lat        (lat) float64 584B 90.0 87.5 85.0 82.5 ... -85.0 -87.5 -90.0
#   * level      (level) float64 296B 1.0 2.0 3.0 5.0 ... 925.0 950.0 975.0 1e+03
# Dimensions without coordinates: bnds
# Data variables:
#     u          (time, level, lat, lon) float32 34GB dask.array<chunksize=(30, 37, 73, 144), meta=np.ndarray>
#     v          (time, level, lat, lon) float32 34GB dask.array<chunksize=(30, 37, 73, 144), meta=np.ndarray>
#     t          (time, level, lat, lon) float32 34GB dask.array<chunksize=(30, 37, 73, 144), meta=np.ndarray>
#     omega      (time, level, lat, lon) float32 34GB dask.array<chunksize=(30, 37, 73, 144), meta=np.ndarray>
# ...

# %% [markdown]
# # Daily anomalies (1979-2010)

# %%
am.run_eof_calculations_and_plot(ds, data_freq='day', time_frame='all-time', time_period='simpson')
# Out:
# Computing EOFs and saving to /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_all-time_daily_anom_lat20-85_100-1000hPa.nc
# Computing EOFs and saving to /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_va_all-time_daily_anom_lat20-85_100-1000hPa.nc

# %%
am.run_eof_calculations_and_plot(ds, data_freq='day', time_frame='jja', time_period='simpson')
# Out:
# Computing EOFs and saving to /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_JJA_daily_anom_lat20-85_100-1000hPa.nc
# Computing EOFs and saving to /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_va_JJA_daily_anom_lat20-85_100-1000hPa.nc

# %%
am.run_eof_calculations_and_plot(ds, data_freq='day', time_frame='jas', time_period='simpson')
# Out:
# Computing EOFs and saving to /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_JAS_daily_anom_lat20-85_100-1000hPa.nc
# Computing EOFs and saving to /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_va_JAS_daily_anom_lat20-85_100-1000hPa.nc

# %%
am.run_eof_calculations_and_plot(ds, data_freq='day', time_frame='djf', time_period='simpson')
# Out:
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_DJF_daily_anom_100-1000hPa.nc
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_va_DJF_daily_anom_100-1000hPa.nc

# %% [markdown]
# # Monthly anomalies (1979-2010)

# %%
am.run_eof_calculations_and_plot(ds, data_freq='month', time_frame='all-time', time_period='simpson')
# Out:
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_all-time_mon_anom_100-1000hPa.nc
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_va_all-time_mon_anom_100-1000hPa.nc

# %%
am.run_eof_calculations_and_plot(ds, data_freq='month', time_frame='jja', time_period='simpson')
# Out:
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_JJA_mon_anom_100-1000hPa.nc
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_va_JJA_mon_anom_100-1000hPa.nc

# %%
am.run_eof_calculations_and_plot(ds, data_freq='month', time_frame='djf', time_period='simpson')
# Out:
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_DJF_mon_anom_100-1000hPa.nc
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_va_DJF_mon_anom_100-1000hPa.nc

# %% [markdown]
# # Seasonal anomalies (1979-2010)

# %%
am.run_eof_calculations_and_plot(ds, data_freq='season', time_frame='all-time', time_period='simpson')
# Out:
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_all-time_szn_anom_100-1000hPa.nc
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_va_all-time_szn_anom_100-1000hPa.nc

# %%
am.run_eof_calculations_and_plot(ds, data_freq='season', time_frame='jja', time_period='simpson')
# Out:
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_JJA_szn_anom_100-1000hPa.nc
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_va_JJA_szn_anom_100-1000hPa.nc

# %%
am.run_eof_calculations_and_plot(ds, data_freq='season', time_frame='djf', time_period='simpson')
# Out:
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_DJF_szn_anom_100-1000hPa.nc
# Loading existing EOFs from /home/links/ct715/eddy_feedback/chapter1/annular_modes/data/eofs/jra55/jra55_1979-2010_sh_eofs_va_DJF_szn_anom_100-1000hPa.nc
