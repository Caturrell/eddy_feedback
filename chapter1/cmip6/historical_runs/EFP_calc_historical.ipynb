# %%
import xarray as xr
import numpy as np
import os
import glob

# %%
path = '/gws/ssde/j25a/arctic_connect/cturrell/CMIP6/historical'
model_path = os.path.join(path, 'AWI-ESM-1-1-LR/1850_2000/6hrPlevPt/yearly_data')

epf_path = glob.glob(model_path + '/*_epflux.nc')
epf_path = sorted(epf_path)
epf = xr.open_mfdataset(epf_path)
epf
# Out:
# <xarray.Dataset> Size: 23GB
# Dimensions:                    (time: 219144, pfull: 6, lat: 96, lon: 192)
# Coordinates:
#   * time                       (time) datetime64[ns] 2MB 1850-01-01T06:00:00 ...
#   * pfull                      (pfull) float64 48B 925.0 850.0 ... 500.0 250.0
#   * lat                        (lat) float64 768B -88.57 -86.72 ... 86.72 88.57
#   * lon                        (lon) float64 2kB 0.0 1.875 3.75 ... 356.2 358.1
# Data variables: (12/24)
#     ep1_QG                     (time, pfull, lat) float32 505MB dask.array<chunksize=(1460, 6, 96), meta=np.ndarray>
#     ep2_QG                     (time, pfull, lat) float64 1GB dask.array<chunksize=(1460, 6, 96), meta=np.ndarray>
#     div1_QG                    (time, pfull, lat) float64 1GB dask.array<chunksize=(1460, 6, 96), meta=np.ndarray>
#     div2_QG                    (time, pfull, lat) float64 1GB dask.array<chunksize=(1460, 6, 96), meta=np.ndarray>
# ...

# %%
daily_path = glob.glob(model_path + '/*_daily_averages.nc')
daily_path = sorted(daily_path)
daily = xr.open_mfdataset(daily_path)
daily
# Out:
# <xarray.Dataset> Size: 79GB
# Dimensions:                    (time: 54936, pfull: 6, bnds: 2, lat: 96,
#                                 lon: 192)
# Coordinates:
#   * pfull                      (pfull) float64 48B 925.0 850.0 ... 500.0 250.0
#   * lat                        (lat) float64 768B -88.57 -86.72 ... 86.72 88.57
#   * lon                        (lon) float64 2kB 0.0 1.875 3.75 ... 356.2 358.1
#   * time                       (time) datetime64[ns] 439kB 1850-01-01 ... 200...
# Dimensions without coordinates: bnds
# Data variables: (12/31)
#     plev_bnds                  (time, pfull, bnds) float64 5MB dask.array<chunksize=(366, 6, 2), meta=np.ndarray>
#     lat_bnds                   (time, lat, bnds) float64 84MB dask.array<chunksize=(366, 96, 2), meta=np.ndarray>
#     lon_bnds                   (time, lon, bnds) float64 169MB dask.array<chunksize=(366, 192, 2), meta=np.ndarray>
# ...
