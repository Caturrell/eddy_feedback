# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

import functions.eddy_feedback as ef

from pypalettes import load_cmap

# %%
source_path = '/home/links/ct715/data_storage/reanalysis/jra55_daily/various_efp_methods'

ds = xr.open_mfdataset(f'{source_path}/daily_ubar_epf-pr-QG_1MS_1958-2016.nc', combine='by_coords')
ds
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility. Expected 16 from C header, got 96 from PyObject
# <xarray.Dataset> Size: 38MB
# Dimensions:  (time: 708, level: 37, lat: 73)
# Coordinates:
#   * lat      (lat) float64 584B -90.0 -87.5 -85.0 -82.5 ... 82.5 85.0 87.5 90.0
#   * level    (level) float64 296B 1e+03 975.0 950.0 925.0 ... 5.0 3.0 2.0 1.0
#   * time     (time) datetime64[ns] 6kB 1958-01-01 1958-02-01 ... 2016-12-01
# Data variables:
#     ubar     (time, level, lat) float32 8MB dask.array<chunksize=(708, 37, 73), meta=np.ndarray>
#     div1_pr  (time, level, lat) float64 15MB dask.array<chunksize=(708, 37, 73), meta=np.ndarray>
#     div1_QG  (time, level, lat) float64 15MB dask.array<chunksize=(708, 37, 73), meta=np.ndarray>

# %%
ds2 = xr.open_mfdataset(f'{source_path}/6h_ubar_epf-pr-QG_1MS_1958-2016.nc', combine='by_coords')
ds2
# Out:
# <xarray.Dataset> Size: 38MB
# Dimensions:  (time: 708, level: 37, lat: 73)
# Coordinates:
#   * lat      (lat) float64 584B -90.0 -87.5 -85.0 -82.5 ... 82.5 85.0 87.5 90.0
#   * level    (level) float64 296B 1e+03 975.0 950.0 925.0 ... 5.0 3.0 2.0 1.0
#   * time     (time) datetime64[ns] 6kB 1958-01-01 1958-02-01 ... 2016-12-01
# Data variables:
#     ubar     (time, level, lat) float32 8MB dask.array<chunksize=(708, 37, 73), meta=np.ndarray>
#     div1_pr  (time, level, lat) float64 15MB dask.array<chunksize=(708, 37, 73), meta=np.ndarray>
#     div1_QG  (time, level, lat) float64 15MB dask.array<chunksize=(708, 37, 73), meta=np.ndarray>

# %%
ds.equals(ds2)
# Out:
# False

# %%
ef.calculate_efp(ds, data_type='reanalysis', which_div1='div1_pr')
# Out:
# 0.3846

# %%
ef.calculate_efp(ds2, data_type='reanalysis', which_div1='div1_pr')
# Out:
# 0.4498

# %% [markdown]
# # Source files

# %%
source_path = '/home/links/ct715/data_storage/reanalysis/jra55_daily/split_years_1958-2016'

ds = xr.open_mfdataset(f'{source_path}/daily_uvtw/pr_epf_uvtw/*.nc', combine='by_coords')
ds
# Out:
# <xarray.Dataset> Size: 136GB
# Dimensions:  (time: 21550, level: 37, lat: 73, lon: 144)
# Coordinates:
#   * time     (time) datetime64[ns] 172kB 1958-01-01T09:00:00 ... 2016-12-31T0...
#   * lon      (lon) float64 1kB 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * lat      (lat) float64 584B -90.0 -87.5 -85.0 -82.5 ... 82.5 85.0 87.5 90.0
#   * level    (level) float64 296B 1e+03 975.0 950.0 925.0 ... 5.0 3.0 2.0 1.0
#     year     (time) int32 86kB dask.array<chunksize=(365,), meta=np.ndarray>
# Data variables:
#     u        (time, level, lat, lon) float32 34GB dask.array<chunksize=(365, 37, 73, 144), meta=np.ndarray>
#     v        (time, level, lat, lon) float32 34GB dask.array<chunksize=(365, 37, 73, 144), meta=np.ndarray>
#     t        (time, level, lat, lon) float32 34GB dask.array<chunksize=(365, 37, 73, 144), meta=np.ndarray>
#     omega    (time, level, lat, lon) float32 34GB dask.array<chunksize=(365, 37, 73, 144), meta=np.ndarray>
# ...

# %%
ds2 = xr.open_mfdataset(f'{source_path}/6h_uvtw/daily_averages/pr_epf_uvtw/*.nc', combine='by_coords')
ds2
# Out:
# <xarray.Dataset> Size: 136GB
# Dimensions:  (time: 21550, level: 37, lat: 73, lon: 144)
# Coordinates:
#   * lon      (lon) float64 1kB 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * lat      (lat) float64 584B -90.0 -87.5 -85.0 -82.5 ... 82.5 85.0 87.5 90.0
#   * level    (level) float64 296B 1e+03 975.0 950.0 925.0 ... 5.0 3.0 2.0 1.0
#     year     (time) int64 172kB 1958 1958 1958 1958 1958 ... 2016 2016 2016 2016
#   * time     (time) datetime64[ns] 172kB 1958-01-01 1958-01-02 ... 2016-12-31
# Data variables:
#     u        (time, level, lat, lon) float32 34GB dask.array<chunksize=(365, 37, 73, 144), meta=np.ndarray>
#     v        (time, level, lat, lon) float32 34GB dask.array<chunksize=(365, 37, 73, 144), meta=np.ndarray>
#     t        (time, level, lat, lon) float32 34GB dask.array<chunksize=(365, 37, 73, 144), meta=np.ndarray>
#     omega    (time, level, lat, lon) float32 34GB dask.array<chunksize=(365, 37, 73, 144), meta=np.ndarray>
# ...

# %%
# ds.equals(ds2)

# %%
ef.calculate_efp(ds, data_type='reanalysis', which_div1='div1_pr')
# Out:
# 0.3858

# %%
ef.calculate_efp(ds2, data_type='reanalysis', which_div1='div1_pr')
# Out:
# 0.4512
