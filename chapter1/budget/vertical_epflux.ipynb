# %%
import xarray as xr

import functions.plotting as plot

# %%
path = '/home/links/ct715/data_storage/reanalysis/jra55_daily/djf_datasets'
ds = xr.open_mfdataset(
    path+'/jra55_djf_uvtw_ubar_ep.nc'
)
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 5325, lon: 144, lat: 73, level: 37)
# Coordinates:
#   * time     (time) datetime64[ns] 1958-01-01T09:00:00 ... 2016-12-31T09:00:00
#   * lon      (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * lat      (lat) float64 90.0 87.5 85.0 82.5 80.0 ... -82.5 -85.0 -87.5 -90.0
#   * level    (level) float64 1.0 2.0 3.0 5.0 7.0 ... 925.0 950.0 975.0 1e+03
# Data variables:
#     v        (time, level, lat, lon) float32 dask.array<chunksize=(1, 37, 73, 144), meta=np.ndarray>
#     t        (time, level, lat, lon) float32 dask.array<chunksize=(1, 37, 73, 144), meta=np.ndarray>
#     omega    (time, level, lat, lon) float32 dask.array<chunksize=(1, 37, 73, 144), meta=np.ndarray>
#     u        (time, level, lat, lon) float32 dask.array<chunksize=(1, 37, 73, 144), meta=np.ndarray>
#     ep1      (time, level, lat) float64 dask.array<chunksize=(1, 37, 73), meta=np.ndarray>
# ...

# %%
plot.plot_reanalysis_correlation(ds, title_name='Correlation with divFz', which_div1='div2', take_seasonal=False)

# %%
plot.plot_reanalysis_correlation(ds, title_name='divFz', which_div1='div2', take_seasonal=False, logscale=False)

# %% [markdown]
# # Full dataset

# %%
path = '/home/links/ct715/data_storage/reanalysis/jra55_daily'
ds = xr.open_mfdataset(
    path+'/jra55_uvtw_ubar_ep.nc'
)
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 21550, level: 37, lat: 73, lon: 144)
# Coordinates:
#   * time     (time) datetime64[ns] 1958-01-01T09:00:00 ... 2016-12-31T09:00:00
#   * lon      (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * lat      (lat) float64 90.0 87.5 85.0 82.5 80.0 ... -82.5 -85.0 -87.5 -90.0
#   * level    (level) float64 1.0 2.0 3.0 5.0 7.0 ... 925.0 950.0 975.0 1e+03
# Data variables:
#     u        (time, level, lat, lon) float32 dask.array<chunksize=(21550, 37, 73, 144), meta=np.ndarray>
#     v        (time, level, lat, lon) float32 dask.array<chunksize=(21550, 37, 73, 144), meta=np.ndarray>
#     t        (time, level, lat, lon) float32 dask.array<chunksize=(21550, 37, 73, 144), meta=np.ndarray>
#     omega    (time, level, lat, lon) float32 dask.array<chunksize=(21550, 37, 73, 144), meta=np.ndarray>
#     ubar     (time, level, lat) float32 dask.array<chunksize=(21550, 37, 73), meta=np.ndarray>
# ...

# %%
plot.plot_reanalysis_correlation(ds, title_name='divFz', which_div1='div2')
# Out:
# /emmy-noether/home/ct715/miniforge3/envs/eddy/lib/python3.12/site-packages/xarray/core/indexing.py:1446: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]

# %%
plot.plot_reanalysis_correlation(ds, title_name='divFz', which_div1='div2', logscale=False)
# Out:
# /emmy-noether/home/ct715/miniforge3/envs/eddy/lib/python3.12/site-packages/xarray/core/indexing.py:1446: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
