# %%
import xarray as xr 
import glob 
import matplotlib.pyplot as plt 
import numpy as np

import sys
sys.path.append('/home/users/cturrell/documents/eddy_feedback/')
import functions.data_wrangling as data 
import functions.plotting as plot

# %% [markdown]
# ### AWI-CM-1-1-MR

# %%
awi = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/AWI_3x3_ef.nc')

plot.plot_pamip_correlation(awi, take_seasonal=False, cut_poles=84, label='AWI-CM-1-1-MR')

# %% [markdown]
# ### CanESM5

# %% [markdown]
# ### CNRM-CM6-1

# %% [markdown]
# ### FGOALS-f3-L

# %%
fgoals = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/FGOALS-f3-L_3x3_ef.nc')

plot.plot_pamip_correlation(fgoals, take_seasonal=False, cut_poles=84, label='FGOALS-f3-L')

# %% [markdown]
# ### HadGEM3-GC31-MM

# %% [markdown]
# ### IPSL-CM6A-LR
