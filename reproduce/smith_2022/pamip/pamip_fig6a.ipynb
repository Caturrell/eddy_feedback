# %%
import xarray as xr 
import glob 
import matplotlib.pyplot as plt 
import numpy as np

import sys
sys.path.append('/home/users/cturrell/documents/eddy_feedback/')
import functions.data_wrangling as data 
import functions.plotting as plot
import functions.eddy_feedback as ef

# %% [markdown]
# ### AWI-CM-1-1-MR

# %%
awi = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/pdSST-pdSIC_3x3/3x3_ef_AWI.nc')
awi = awi.convert_calendar('noleap')

efp_awi_north = ef.calculate_efp_pamip(awi)
efp_awi_south = ef.calculate_efp_pamip(awi, calc_south_hemis=True)
print(f'NH EFP: {efp_awi_north} \nSH EFP: {efp_awi_south}')

plot.plot_pamip_correlation(awi, take_seasonal=False, cut_poles=84, label='AWI-CM-1-1-MR')
# Out:
# NH EFP: 0.29
# SH EFP: 0.3

# %% [markdown]
# ### CanESM5

# %%
can = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/pdSST-pdSIC_3x3/3x3_ef_CanESM5.nc')

efp_can_north = ef.calculate_efp_pamip(can)
efp_can_south = ef.calculate_efp_pamip(can, calc_south_hemis=True)
print(f'NH EFP: {efp_can_north} \nSH EFP: {efp_can_south}')

plot.plot_pamip_correlation(can, take_seasonal=False, cut_poles=84, label='CanESM5')
# Out:
# NH EFP: 0.34
# SH EFP: 0.33

# %% [markdown]
# ### CNRM-CM6-1

# %%
cnrm = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/pdSST-pdSIC_3x3/3x3_ef_CNRM.nc')

efp_cnrm_north = ef.calculate_efp_pamip(cnrm)
efp_cnrm_south = ef.calculate_efp_pamip(cnrm, calc_south_hemis=True)
print(f'NH EFP: {efp_cnrm_north} \nSH EFP: {efp_cnrm_south}')

plot.plot_pamip_correlation(cnrm, take_seasonal=False, cut_poles=84, label='CNRM-f3-L')
# Out:
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/dask/array/numpy_compat.py:51: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# NH EFP: 0.27
# SH EFP: 0.22

# %% [markdown]
# ### FGOALS-f3-L

# %%
fgoals = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/pdSST-pdSIC_3x3/3x3_ef_FGOALS.nc')

efp_fgoals_north = ef.calculate_efp_pamip(fgoals)
efp_fgoals_south = ef.calculate_efp_pamip(fgoals, calc_south_hemis=True)
print(f'NH EFP: {efp_fgoals_north} \nSH EFP: {efp_fgoals_south}')

plot.plot_pamip_correlation(fgoals, take_seasonal=False, cut_poles=84, label='FGOALS-f3-L')
# Out:
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# NH EFP: 0.28
# SH EFP: 0.15

# %% [markdown]
# ### HadGEM3-GC31-MM

# %%
had = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/pdSST-pdSIC_3x3/3x3_ef_HadGEM.nc')

efp_had_north = ef.calculate_efp_pamip(had)
efp_had_south = ef.calculate_efp_pamip(had, calc_south_hemis=True)
print(f'NH EFP: {efp_had_north} \nSH EFP: {efp_had_south}')

plot.plot_pamip_correlation(had, take_seasonal=False, cut_poles=84, label='HadGEM3-GM31-MM')
# Out:
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/dask/array/numpy_compat.py:51: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# NH EFP: 0.19
# SH EFP: 0.2

# %% [markdown]
# ### IPSL-CM6A-LR

# %%
ipsl = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/pdSST-pdSIC_3x3/3x3_ef_IPSL.nc')

efp_ipsl_north = ef.calculate_efp_pamip(ipsl)
efp_ipsl_south = ef.calculate_efp_pamip(ipsl, calc_south_hemis=True)
print(f'NH EFP: {efp_ipsl_north} \nSH EFP: {efp_ipsl_south}')

plot.plot_pamip_correlation(ipsl, take_seasonal=False, cut_poles=84, label='IPSL-CM6A-LR')
# Out:
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/dask/array/numpy_compat.py:51: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# NH EFP: 0.31
# SH EFP: 0.23

# %% [markdown]
# ### MIRCO6

# %%
miroc = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/PAMIP_data/regridded/pdSST-pdSIC_3x3/3x3_ef_MIROC.nc')

efp_miroc_north = ef.calculate_efp_pamip(miroc)
efp_miroc_south = ef.calculate_efp_pamip(miroc, calc_south_hemis=True)
print(f'NH EFP: {efp_miroc_north} \nSH EFP: {efp_miroc_south}')

plot.plot_pamip_correlation(miroc, take_seasonal=False, cut_poles=84, label='MIROC6')
# Out:
# /home/users/cturrell/miniforge3/envs/eddy/lib/python3.12/site-packages/dask/array/numpy_compat.py:51: RuntimeWarning: invalid value encountered in divide
#   x = np.divide(x1, x2, out)
# NH EFP: 0.19
# SH EFP: 0.22

# %% [markdown]
# ## Multi-model Mean

# %%
ipsl
# Out:
# <xarray.Dataset>
# Dimensions:  (ens_ax: 200, time: 426, level: 19, lat: 61)
# Coordinates:
#   * level    (level) float32 1e+03 925.0 850.0 700.0 600.0 ... 20.0 10.0 5.0 1.0
#   * time     (time) datetime64[ns] 2000-04-01T12:00:00 ... 2001-05-31T12:00:00
#   * lat      (lat) int64 -90 -87 -84 -81 -78 -75 -72 ... 72 75 78 81 84 87 90
# Dimensions without coordinates: ens_ax
# Data variables:
#     ubar     (ens_ax, time, level, lat) float32 dask.array<chunksize=(200, 426, 19, 61), meta=np.ndarray>
#     div1     (ens_ax, time, level, lat) float64 dask.array<chunksize=(200, 426, 19, 61), meta=np.ndarray>

# %% [markdown]
# # Jacked Isca

# %%
isca = xr.open_mfdataset('/gws/nopw/j04/arctic_connect/cturrell/isca_data/realistic_V2_uvt_ubar_ep-both.nc',
                         parallel=True, chunks={'time':30})
isca = data.seasonal_mean(isca, cut_ends=False, season='djf')
isca = isca.isel(time=slice(1,-1))
isca
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 40, level: 40, lat: 64, lon: 128)
# Coordinates:
#   * lon      (lon) float64 0.0 2.812 5.625 8.438 ... 348.8 351.6 354.4 357.2
#   * lat      (lat) float64 -87.86 -85.1 -82.31 -79.53 ... 79.53 82.31 85.1 87.86
#   * level    (level) float32 0.03 0.16 0.51 1.38 ... 825.0 871.8 921.0 973.1
#   * time     (time) object 0022-12-01 00:00:00 ... 0061-12-01 00:00:00
# Data variables:
#     u        (time, level, lat, lon) float32 -1.242 -1.241 ... -0.8717 -0.7938
#     v        (time, level, lat, lon) float32 0.1152 0.1073 ... 1.953 1.926
#     t        (time, level, lat, lon) float32 261.2 261.2 261.2 ... 255.0 255.0
#     ubar     (time, level, lat) float32 -1.093 -2.51 -3.937 ... 1.188 0.674
#     div1_pr  (time, level, lat) float64 -0.003185 -0.003804 ... -0.1517 1.512
#     div1_qg  (time, level, lat) float64 -0.003185 -0.003804 ... -0.1517 1.512

# %%
efp_isca_north = ef.calculate_efp(isca, take_seasonal=False)
efp_isca_south = ef.calculate_efp(isca, calc_south_hemis=True, take_seasonal=False)
print(f'NH EFP: {efp_isca_north} \nSH EFP: {efp_isca_south}')

plot.plot_reanalysis_correlation(isca, take_seasonal=False, label='Realistic Isca')
# Out:
# Seasonal average has not been calculated.
#
# Seasonal average has not been calculated.
#
# NH EFP: 0.31
# SH EFP: 0.35

# %%
awi.time[:20]
# Out:
# <xarray.DataArray 'time' (time: 20)>
# array([cftime.DatetimeNoLeap(2000, 6, 1, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2000, 6, 2, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2000, 6, 3, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2000, 6, 4, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2000, 6, 5, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2000, 6, 6, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2000, 6, 7, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2000, 6, 8, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2000, 6, 9, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2000, 6, 10, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2000, 6, 11, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2000, 6, 12, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2000, 6, 13, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2000, 6, 14, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2000, 6, 15, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2000, 6, 16, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2000, 6, 17, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2000, 6, 18, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2000, 6, 19, 12, 0, 0, 0, has_year_zero=True),
#        cftime.DatetimeNoLeap(2000, 6, 20, 12, 0, 0, 0, has_year_zero=True)],
#       dtype=object)
# Coordinates:
#   * time     (time) object 2000-06-01 12:00:00 ... 2000-06-20 12:00:00
