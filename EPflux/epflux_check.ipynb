# %%
import xarray as xr

# %%
ds = xr.open_mfdataset('/home/links/ct715/eddy_feedback/daily_datasets/jra55_uvtw_ep.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 21550, lon: 144, lat: 73, level: 37)
# Coordinates:
#   * time     (time) datetime64[ns] 1958-01-01T09:00:00 ... 2016-12-31T09:00:00
#   * lon      (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * lat      (lat) float64 90.0 87.5 85.0 82.5 80.0 ... -82.5 -85.0 -87.5 -90.0
#   * level    (level) float64 1.0 2.0 3.0 5.0 7.0 ... 925.0 950.0 975.0 1e+03
# Data variables:
#     v        (time, level, lat, lon) float32 dask.array<chunksize=(21550, 37, 73, 144), meta=np.ndarray>
#     t        (time, level, lat, lon) float32 dask.array<chunksize=(21550, 37, 73, 144), meta=np.ndarray>
#     omega    (time, level, lat, lon) float32 dask.array<chunksize=(21550, 37, 73, 144), meta=np.ndarray>
#     u        (time, level, lat, lon) float32 dask.array<chunksize=(21550, 37, 73, 144), meta=np.ndarray>
#     ubar     (level, lat) float32 dask.array<chunksize=(37, 73), meta=np.ndarray>
# ...

# %%
ds = ds[['u', 'v', 't', 'omega']]
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 21550, level: 37, lat: 73, lon: 144)
# Coordinates:
#   * time     (time) datetime64[ns] 1958-01-01T09:00:00 ... 2016-12-31T09:00:00
#   * lon      (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * lat      (lat) float64 90.0 87.5 85.0 82.5 80.0 ... -82.5 -85.0 -87.5 -90.0
#   * level    (level) float64 1.0 2.0 3.0 5.0 7.0 ... 925.0 950.0 975.0 1e+03
# Data variables:
#     u        (time, level, lat, lon) float32 dask.array<chunksize=(21550, 37, 73, 144), meta=np.ndarray>
#     v        (time, level, lat, lon) float32 dask.array<chunksize=(21550, 37, 73, 144), meta=np.ndarray>
#     t        (time, level, lat, lon) float32 dask.array<chunksize=(21550, 37, 73, 144), meta=np.ndarray>
#     omega    (time, level, lat, lon) float32 dask.array<chunksize=(21550, 37, 73, 144), meta=np.ndarray>

# %%
ds.to_netcdf('/home/links/ct715/eddy_feedback/daily_datasets/jra55_uvtw.nc')
