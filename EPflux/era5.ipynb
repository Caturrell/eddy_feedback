# %%
import xarray as xr

# %% [markdown]
# ### Maths Servers:

# %%
# import sys
# sys.path.append('/home/links/ct715/eddy_feedback/')
# import functions.eddy_feedback as ef 

# # import dataset for maths servers
# ds = xr.open_mfdataset('/home/links/ct715/eddy_feedback/daily_datasets/era5daily_uvt.nc',
#                             parallel=True, chunks={'time': 31})

# ds

# %% [markdown]
# ### JASMIN Servers:

# %%
import sys
sys.path.append('/home/users/cturrell/documents/eddy_feedback/')
import functions.eddy_feedback as ef 

# import dataset for JASMIN servers
ds = xr.open_mfdataset('/home/users/cturrell/documents/eddy_feedback/daily_datasets/era5daily_uvt.nc',
                            parallel=True, chunks={'time': 31})

ds
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 6
#       3 import functions.eddy_feedback as ef
#       5 # import dataset for JASMIN servers
# ----> 6 ds = xr.open_mfdataset('/home/users/cturrell/documents/eddy_feedback/daily_datasets/era5daily_uvt.nc',
#       7                             parallel=True, chunks={'time': 31})
#       9 ds
#
# File ~/miniforge3/envs/eddy/lib/python3.12/site-packages/xarray/backends/api.py:990, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#     987 paths = _find_absolute_paths(paths, engine=engine, **kwargs)
#     989 if not paths:
# --> 990     raise OSError("no files to open")
#     992 if combine == "nested":
#     993     if isinstance(concat_dim, (str, DataArray)) or concat_dim is None:
#
# ...

# %%
ds = ef.calculate_epfluxes_ubar(ds)
ds
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /emmy-noether/home/ct715/miniforge3/envs/eddy/lib/python3.12/site-packages/xarray/namedarray/core.py:666, in NamedArray._get_axis_num(self, dim)
#     665 try:
# --> 666     return self.dims.index(dim)  # type: ignore[no-any-return]
#     667 except ValueError:
#
# ValueError: tuple.index(x): x not in tuple
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ds = ef.calculate_epfluxes_ubar(ds)
#       2 ds
#
# File ~/eddy_feedback/functions/eddy_feedback.py:164, in calculate_epfluxes_ubar(ds, primitive)
#     162 # check if ubar is in dataset also
#     163 if not 'ubar' in ds:
# --> 164     ds = calculate_ubar(ds)
#     167 import functions.aos_functions as aos
# ...

# %%
ef.plot_ubar(ds)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ef.plot_ubar(ds)
#
# File ~/documents/eddy_feedback/functions/eddy_feedback.py:256, in plot_ubar(ds, label, figsize, latitude, top_atmos, show_rect, orientation, location, extend, shrink, levels, yincrease, yscale, round_sf, savefig, fig_label)
#     249 #-------------------------------------------------------------------
#     250
#     251 ## PLOTTING TIME
#     252
#     253 # set figure
#     254 plt.figure(figsize=figsize)
# --> 256 plt.contourf(ubar.lat.values, ubar.level.values, ubar,
#     257              cmap=coolwarm, levels=lvl, extend=extend)
#     258 plt.colorbar(location=location, orientation=orientation, shrink=shrink,
#     259          label='Wind speed (m/s)', extend=extend, ticks=ticks)
#     261 plt.title(f'{label}')
#
# ...

# %%
ef.plot_ubar_epflux(ds, skip_lat=3)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
ef.plot_epfluxes_div(ds, latitude='NH')
# Out:
# Failed to start the Kernel 'eddy (Python 3.12.0)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unknown system error -122: Unknown system error -122, open '/home/users/cturrell/.local/share/jupyter/runtime/kernel-v2-31038goDrxJFhejLV.json'

# %%
# Out:
# Failed to start the Kernel 'eddy (Python 3.12.0)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unknown system error -122: Unknown system error -122, open '/home/users/cturrell/.local/share/jupyter/runtime/kernel-v2-31038goDrxJFhejLV.json'
